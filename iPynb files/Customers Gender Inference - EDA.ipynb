# %% [markdown]
# # GFG Data Scientist Task - Exploratory data analysis (EDA)

# %% [markdown]
# This Jupyter Notebook gives a flavor of my thought process while exploring the data

# %%
# Import libraries

import pandas as pd
import numpy as np
from scipy import stats
pd.set_option('display.max_columns', None)

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import defaultdict

from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression

# %%
# Read the json file provided on the github page

df_json = pd.read_json('data.json', orient='record')

# %%
# Create the dataframe

df_raw = pd.read_json(df_json.iloc[0,0], orient='record')

# %% [markdown]
# ### High-level exploratory analysis

# %%
# Shape of the original dataframe

df_raw.shape
# Out:
# (191287, 33)

# %%
# Make sure there is no missing value

df_raw.isna().sum()
# Out:
# days_since_first_order      0
# days_since_last_order       0
# is_newsletter_subscriber    0
# orders                      0
# items                       0
# returns                     0
# different_addresses         0
# shipping_addresses          0
# devices                     0
# vouchers                    0
# cc_payments                 0
# paypal_payments             0
# afterpay_payments           0
# female_items                0
# male_items                  0
# unisex_items                0
# wapp_items                  0
# wftw_items                  0
# mapp_items                  0
# wacc_items                  0
# macc_items                  0
# mftw_items                  0
# sprt_items                  0
# msite_orders                0
# desktop_orders              0
# android_orders              0
# ios_orders                  0
# work_orders                 0
# home_orders                 0
# parcelpoint_orders          0
# coupon_discount_applied     0
# revenue                     0
# customer_id                 0
# dtype: int64

# %%
# Look at the columns types

df_raw.dtypes
# Out:
# days_since_first_order        int64
# days_since_last_order         int64
# is_newsletter_subscriber     object
# orders                        int64
# items                         int64
# returns                       int64
# different_addresses           int64
# shipping_addresses            int64
# devices                       int64
# vouchers                      int64
# cc_payments                   int64
# paypal_payments               int64
# afterpay_payments             int64
# female_items                  int64
# male_items                    int64
# unisex_items                  int64
# wapp_items                    int64
# wftw_items                    int64
# mapp_items                    int64
# wacc_items                    int64
# macc_items                    int64
# mftw_items                    int64
# sprt_items                    int64
# msite_orders                  int64
# desktop_orders                int64
# android_orders                int64
# ios_orders                    int64
# work_orders                   int64
# home_orders                   int64
# parcelpoint_orders            int64
# coupon_discount_applied     float64
# revenue                     float64
# customer_id                 float64
# dtype: object

# %%
# Convert 'is_newsletter_subscriber' into 1 or 0 (1='Yes', 0 ='No').

df_raw['is_newsletter_subscriber'] = np.where(df_raw['is_newsletter_subscriber']=='Y',1,0)

# %%
# Check if there is any duplicated customer_id

df_raw['customer_id'].duplicated().sum()
# Out:
# 0

# %%
# First glance at each column

for i in df_raw.columns:
    print(df_raw[f"{i}"].describe())
    print(' ')
# Out:
# count    191287.000000
# mean       2325.415344
# std         382.012579
# min           3.000000
# 25%        2271.000000
# 50%        2414.000000
# 75%        2526.000000
# max        2813.000000
# Name: days_since_first_order, dtype: float64
#
# count    191287.000000
# mean        862.390832
# std         832.876737
# min           0.000000
# 25%          92.000000
# 50%         544.000000
# 75%        1659.000000
# max        2329.000000
# Name: days_since_last_order, dtype: float64
#
# count    191287.000000
# mean          0.661096
# std           0.473339
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: is_newsletter_subscriber, dtype: float64
#
# count    191287.000000
# mean         10.841887
# std          19.191299
# min           1.000000
# 25%           2.000000
# 50%           4.000000
# 75%          12.000000
# max        1289.000000
# Name: orders, dtype: float64
#
# count    191287.000000
# mean         24.544668
# std          50.868840
# min           1.000000
# 25%           3.000000
# 50%           8.000000
# 75%          25.000000
# max        3020.000000
# Name: items, dtype: float64
#
# count    191287.000000
# mean          7.075745
# std          25.923825
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           4.000000
# max        2022.000000
# Name: returns, dtype: float64
#
# count    191287.000000
# mean          1.258392
# std           8.920020
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        1996.000000
# Name: different_addresses, dtype: float64
#
# count    191287.000000
# mean          2.412438
# std           4.493934
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max        1122.000000
# Name: shipping_addresses, dtype: float64
#
# count    191287.000000
# mean          1.645747
# std           0.734939
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           4.000000
# Name: devices, dtype: float64
#
# count    191287.000000
# mean          3.394993
# std           7.428651
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           4.000000
# max        1135.000000
# Name: vouchers, dtype: float64
#
# count    191287.000000
# mean         13.190337
# std          34.672078
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%          11.000000
# max        2928.000000
# Name: cc_payments, dtype: float64
#
# count    191287.000000
# mean          7.891749
# std          24.887787
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           6.000000
# max        1670.000000
# Name: paypal_payments, dtype: float64
#
# count    191287.000000
# mean          2.942129
# std          13.186908
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         615.000000
# Name: afterpay_payments, dtype: float64
#
# count    191287.000000
# mean         19.975942
# std          45.617789
# min           0.000000
# 25%           1.000000
# 50%           5.000000
# 75%          19.000000
# max        2150.000000
# Name: female_items, dtype: float64
#
# count    191287.000000
# mean          3.759853
# std          11.935671
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max        1115.000000
# Name: male_items, dtype: float64
#
# count    191287.000000
# mean          0.808874
# std           2.016606
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max          75.000000
# Name: unisex_items, dtype: float64
#
# count    191287.000000
# mean         13.846707
# std          34.962568
# min           0.000000
# 25%           0.000000
# 50%           2.000000
# 75%          12.000000
# max        1728.000000
# Name: wapp_items, dtype: float64
#
# count    191287.000000
# mean          3.946588
# std           8.023221
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           4.000000
# max         493.000000
# Name: wftw_items, dtype: float64
#
# count    191287.000000
# mean          2.346830
# std           8.773565
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         947.000000
# Name: mapp_items, dtype: float64
#
# count    191287.000000
# mean          1.745932
# std           4.587027
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max         266.000000
# Name: wacc_items, dtype: float64
#
# count    191287.000000
# mean          0.782965
# std           2.343804
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         206.000000
# Name: macc_items, dtype: float64
#
# count    191287.000000
# mean          0.862097
# std           2.422466
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         151.000000
# Name: mftw_items, dtype: float64
#
# count    191287.000000
# mean          0.238532
# std           0.916521
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          44.000000
# Name: sprt_items, dtype: float64
#
# count    191287.000000
# mean          2.732941
# std           7.253788
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max         373.000000
# Name: msite_orders, dtype: float64
#
# count    191287.000000
# mean          5.700529
# std          11.975780
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           6.000000
# max        1275.000000
# Name: desktop_orders, dtype: float64
#
# count    191287.000000
# mean          0.227517
# std           2.096664
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         244.000000
# Name: android_orders, dtype: float64
#
# count    191287.000000
# mean          2.180901
# std           8.206619
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         357.000000
# Name: ios_orders, dtype: float64
#
# count    191287.000000
# mean          1.203485
# std           5.061593
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         223.000000
# Name: work_orders, dtype: float64
#
# count    191287.000000
# mean          6.038685
# std          12.875926
# min           0.000000
# 25%           0.000000
# 50%           2.000000
# 75%           6.000000
# max         496.000000
# Name: home_orders, dtype: float64
#
# count    191287.000000
# mean          0.101471
# std           1.425184
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         290.000000
# Name: parcelpoint_orders, dtype: float64
#
# count    1.912870e+05
# mean     1.321704e+03
# std      3.905356e+04
# min     -1.559784e+02
# 25%      4.800000e-03
# 50%      5.520000e-02
# 75%      1.466000e-01
# max      5.798000e+06
# Name: coupon_discount_applied, dtype: float64
#
# count    191287.000000
# mean       1515.276901
# std        3508.433432
# min          -1.130000
# 25%         140.840000
# 50%         443.100000
# 75%        1477.225000
# max      205655.020000
# Name: revenue, dtype: float64
#
# count    1.912870e+05
# mean     3.387436e+09
# std      2.094103e+08
# min      3.016870e+09
# 25%      3.202564e+09
# 50%      3.398475e+09
# 75%      3.567305e+09
# max      3.801194e+09
# Name: customer_id, dtype: float64

# %%
print(f"Percentage of customers having ordered an item less than a week ago: {round(df_raw.loc[df_raw['days_since_last_order']<7].shape[0]*100/df_raw.shape[0],1)} %")
# Out:
# Percentage of customers having ordered an item less than a week ago: 4.7 %

# %% [markdown]
# #### Remarks from above
#
# - days_since_first_order: This column looks good.
# - days_since_last_order: This column looks good also the average of last order is more than 2 years !
# - is_newsletter_subscriber: This columns looks ok as well.
# - orders: This column looks good.
# - items: This looks ok as well.
# - returns: This column looks correct although the max is 2022 ! That's a lot of returns. To check in detail later.
# - different_addresses: This columns looks ok.
# - shipping_addresses: This looks ok although the max of different shipping addresses used is 1122. That's a lot of different addresses. To check in detail later.
# - devices: This columns looks fine.
# - vouchers: This looks ok to me.
# - cc_payments: This columns looks good.
# - paypal_payments: Nothing wrong here.
# - afterpay_payments: All good here.
# - female_items: This column looks fine.
# - male_items: Nothing wrong that I can spot there.
# - unisex_items: All good for me.
# - wapp_items: Looks good.
# - wftw_items: This columns looks good as well.
# - mapp_items: Nothing wrong here either.
# - wacc_items: Ok also.
# - macc_items: Looks fine.
# - mftw_items: Looks just fine as well.
# - sprt_items: This is looking good too.
# - msite_orders: Nothing much here.
# - desktop_orders: Pretty normal as well.
# - android_orders: This looks good.
# - ios_orders: This column is fine.
# - work_orders: Pretty normal too.
# - home_orders: This looks good.
# - parcelpoint_orders: This column is ok.
# - <font color=red> __coupon_discount_applied:__ </font> 'coupon_discount_applied' is the average discount rate applied via coupon based discount e.g. SAVE15. It does not make sense to have negative values or values exceeding 100%. We will need to clean this column.
# - <font color=red> __revenue:__ </font> The column 'revenue' is the amount of $ Dollar spent overall per person. Customers are not supposed to spend negative amount of money when purchasing goods. We will need to clean this column as well.
# - customer_id: This column loos fine.
#
#
# __Conclusion:__ <br/>It looks like the 2 columns that need some work (as specified in the problem formulation) are __revenue__ and __coupon_discount_applied__.
# <br/>Also, there are outliers in numerous columns and some weird values here and there. It might be better to get rid of them to fit our model later on.

# %%
# Print histogram for all columns except customer_id.

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

to_remove = ['customer_id']
print_list = [ x for x in df_raw.columns.tolist() if x not in to_remove]

f, axes = plt.subplots(8,4, figsize=(20,20))

for index, col in enumerate(print_list):
    i, j = divmod(index,4)
    sns.distplot(df_raw[f"{col}"],ax=axes[i, j])

plt.tight_layout()
plt.show()

# %%
# Let's take a look at the same graphs without outliers 
# We drop records having any feature above 3 standard deviation.

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

df_raw_no_outliers = df_raw.loc[(np.abs(stats.zscore(df_raw[print_list]))<2).all(axis=1),print_list]
f, axes = plt.subplots(8,4, figsize=(20,20))

for index, col in enumerate(print_list):
    i, j = divmod(index,4)
    sns.distplot(df_raw_no_outliers[f"{col}"],ax=axes[i, j], color='red')

plt.tight_layout()
plt.show()

# %%
# Is there any customer having more returns than orders?

print(f"Percentage of records having 'returns' higher than 'orders': {round(df_raw.loc[df_raw['orders']<df_raw['returns']].shape[0]*100/df_raw.shape[0],1)} %")
# Out:
# Percentage of records having 'returns' higher than 'orders': 9.1 %

# %% [markdown]
# ### Shipping_addresses, female_items, and male_items

# %%
# Let's take a look at records with 'shipping_addresses' above 100
# Maybe those customers bought goods for their numerous friends hence the number of different shipping address?...
# Looks suspicious nonetheless.

df_raw.loc[df_raw['shipping_addresses'] > 100]
# Out:
#         days_since_first_order  days_since_last_order  \
# 10298                     2608                   1455
# 15833                     2580                   1294
# 82799                     2404                   1216
# 101061                    2589                    588
# 106028                    2595                   1405
# 145400                    2145                      6
#
#         is_newsletter_subscriber  orders  items  returns  different_addresses  \
# 10298                          0     574   1099       38                 1087
# 15833                          0     968   1603       90                 1577
# 82799                          0     639   1049       59                 1030
# 101061                         0    1289   2374      181                 1996
# 106028                         0     535    834       55                  786
# 145400                         1     303    624       34                  491
#
#         shipping_addresses  devices  vouchers  cc_payments  paypal_payments  \
# 10298                  539        1       528           10              135
# 15833                  936        1       898           21              106
# 82799                  609        2       485           12              244
# 101061                1122        3      1135          360              150
# 106028                 497        2       501           44               79
# 145400                 237        2       236          102               18
#
#         afterpay_payments  female_items  male_items  unisex_items  wapp_items  \
# 10298                   0           781         283            35         486
# 15833                   0          1194         348            61         659
# 82799                   0           775         253            21         427
# 101061                  0          1796         503            75        1073
# 106028                  0           611         191            32         322
# 145400                 31           393         207            24         252
#
#         wftw_items  mapp_items  wacc_items  macc_items  mftw_items  \
# 10298          192         157         103          93          52
# 15833          393         170         140          86         109
# 82799          225         113          95          51          79
# 101061         493         217         224         166         151
# 106028         222         101          66          51          39
# 145400          96         119          47          67          34
#
#         sprt_items  msite_orders  desktop_orders  android_orders  ios_orders  \
# 10298            3             0             574               0           0
# 15833            8             0             968               0           0
# 82799           12             1             638               0           0
# 101061          18             8            1275               0           6
# 106028           3             6             528               0           1
# 145400           5             2             300               1           0
#
#         work_orders  home_orders  parcelpoint_orders  coupon_discount_applied  \
# 10298             0            0                   0                  16.4487
# 15833             0            3                   0                  11.1167
# 82799             5            2                   0                   3.6408
# 101061            0            1                   0                   7.7072
# 106028            0            2                   0                  23.2940
# 145400           49            3                   0                   4.3754
#
#          revenue   customer_id
# 10298    3018.02  3.046864e+09
# 15833    7379.39  3.027101e+09
# 82799   13719.01  3.274989e+09
# 101061  14651.32  3.403827e+09
# 106028   1970.40  3.416897e+09
# 145400   5687.03  3.643409e+09

# %%
# Difference between female_items and male_items

fig, axes = plt.subplots(1,1,figsize=(10,5))
axes.set_title('Distribution of female_items vs male_items')

df_raw['female_items'].plot(kind='hist', bins=1000, alpha=0.7)
df_raw['male_items'].plot(kind='hist', bins=1000, alpha=0.7)

plt.legend()
plt.xlim(0,100);

# The number of female items is a lot more distributed compared to male items, which is heavely skewed towards 0.

# %%
# Difference between female_items and male_items where shipping_addresses is over quantile 90%

fig, axes = plt.subplots(1,1,figsize=(10,5))

axes.set_title('Distribution of female_items vs male_items where shipping_addresses is over quantile 90%')
df_raw.loc[df_raw['shipping_addresses']> df_raw['shipping_addresses'].quantile(0.9),'female_items'].plot(kind='hist', bins=1000)
df_raw.loc[df_raw['shipping_addresses']> df_raw['shipping_addresses'].quantile(0.9),'male_items'].plot(kind='hist', bins=1000)

plt.legend()
axes.set_xlabel('items')
plt.xlim(0,500)
plt.ylim(0,1500);

# Again, same trend here.

# %%
# We have in average 5 times more female items than male items

df_raw['female_items'].sum()/df_raw['male_items'].sum()
# Out:
# 5.312958227835781

# %%
# For 42% of the records, male_items or female_items is not the sum of app, acc and ftw. 

df_raw.loc[(df_raw['male_items']!=df_raw['mapp_items']+df_raw['macc_items']+df_raw['mftw_items']) | (df_raw['female_items']!=df_raw['wapp_items']+df_raw['wacc_items']+df_raw['wftw_items'])]

# Show ratio
#df_raw.loc[(df_raw['male_items']!=df_raw['mapp_items']+df_raw['macc_items']+df_raw['mftw_items']) | (df_raw['female_items']!=df_raw['wapp_items']+df_raw['wacc_items']+df_raw['wftw_items'])].shape[0]*100/df_raw.shape[0]
# Out:
#         days_since_first_order  days_since_last_order  \
# 0                         2783                   1487
# 1                         2772                   1296
# 3                         2767                      6
# 5                         2764                     18
# 7                         2757                      5
# ...                        ...                    ...
# 191271                    2083                   2083
# 191278                    2393                    624
# 191279                    2132                    154
# 191280                    2234                     32
# 191282                    2223                   2223
#
#         is_newsletter_subscriber  orders  items  returns  different_addresses  \
# 0                              0       2      5        0                    0
# 1                              0       1      1        0                    0
# 3                              1      23     36        3                    0
# 5                              1      36     81       22                    1
# 7                              1      21     58        5                    1
# ...                          ...     ...    ...      ...                  ...
# 191271                         0       1      6        0                    0
# 191278                         0       2      3        0                    0
# 191279                         0       3      8        0                    3
# 191280                         1     187    835      673                   28
# 191282                         1       1      1        1                    0
#
#         shipping_addresses  devices  vouchers  cc_payments  paypal_payments  \
# 0                        2        1         0            5                0
# 1                        1        1         0            1                0
# 3                        3        3        13           24                0
# 5                        3        2         9           21               28
# 7                        4        2         6           30               28
# ...                    ...      ...       ...          ...              ...
# 191271                   1        1         1            0                6
# 191278                   1        1         1            0                3
# 191279                   3        1         0            0                7
# 191280                   4        4        55          832                2
# 191282                   1        1         0            1                0
#
#         afterpay_payments  female_items  male_items  unisex_items  wapp_items  \
# 0                       0             0           4             1           0
# 1                       0             0           0             1           0
# 3                      12            28           1             7           8
# 5                      32            73           6             2          69
# 7                       0             0          55             3           0
# ...                   ...           ...         ...           ...         ...
# 191271                  0             4           2             0           3
# 191278                  0             2           0             1           0
# 191279                  1             7           1             0           2
# 191280                  0           753          60            22         638
# 191282                  0             1           0             0           0
#
#         wftw_items  mapp_items  wacc_items  macc_items  mftw_items  \
# 0                0           3           0           0           2
# 1                0           0           0           0           1
# 3               11           0           2           1           4
# 5                2           3           1           1           4
# 7                0          41           0          11           5
# ...            ...         ...         ...         ...         ...
# 191271           0           1           1           0           0
# 191278           0           0           0           0           1
# 191279           4           0           1           0           0
# 191280          52          43          45          12          11
# 191282           0           0           0           0           0
#
#         sprt_items  msite_orders  desktop_orders  android_orders  ios_orders  \
# 0                0             0               2               0           0
# 1                0             0               1               0           0
# 3                0             8               2               0          13
# 5                1             3              19               0          14
# 7                0             2              19               0           0
# ...            ...           ...             ...             ...         ...
# 191271           0             0               1               0           0
# 191278           0             0               2               0           0
# 191279           0             0               3               0           0
# 191280          26             3             130               5          49
# 191282           0             0               1               0           0
#
#         work_orders  home_orders  parcelpoint_orders  coupon_discount_applied  \
# 0                 0            0                   0                   0.0000
# 1                 0            1                   0                   0.0091
# 3                 0           21                   0                   0.1723
# 5                16           16                   0                   0.0413
# 7                 1           10                   0                   0.0738
# ...             ...          ...                 ...                      ...
# 191271            0            0                   0                   0.2498
# 191278            0            1                   0                   0.0896
# 191279            0            1                   0                   0.0022
# 191280            0          170                   0                   0.2099
# 191282            0            0                   0                   0.0000
#
#          revenue   customer_id
# 0         468.80  3.017001e+09
# 1         109.09  3.017108e+09
# 3        1872.81  3.017185e+09
# 5        7131.31  3.017256e+09
# 7        2625.62  3.017372e+09
# ...          ...           ...
# 191271    230.80  3.706625e+09
# 191278    141.81  3.706942e+09
# 191279    442.49  3.706952e+09
# 191280  68349.19  3.706954e+09
# 191282    163.63  3.706982e+09
#
# [79815 rows x 33 columns]

# %%
# Is there any obvious relationship between male_items and female_items? Hard to say...

sns.displot(data=df_raw,x='female_items', y='male_items',cbar=True, aspect=2)
plt.title('Bivariate distribution plot between male_items and female_items');

# %% [markdown]
# ### Items and returns

# %%
# Records where items is very high and the ratio of returns versus items is also high (more than 97% of the records)

it_qu = df_raw['items'].quantile(0.97)
ratio_qu = (df_raw['returns']/df_raw['items']).quantile(0.97)

df_not_happy = df_raw[(df_raw['items'] > it_qu) & (df_raw['returns']/df_raw['items'] > ratio_qu)]
df_not_happy

# It looks like those customers are often unhappy about their purchases...
# Out:
#         days_since_first_order  days_since_last_order  \
# 434                       2727                     36
# 1380                      1930                     29
# 1421                      2600                     15
# 2332                      2524                      5
# 3385                      2232                     13
# ...                        ...                    ...
# 188937                    2111                     41
# 190627                    2225                     34
# 190824                    2207                     26
# 191226                    2401                      6
# 191280                    2234                     32
#
#         is_newsletter_subscriber  orders  items  returns  different_addresses  \
# 434                            1      29    171      136                    0
# 1380                           1      81    203      171                    0
# 1421                           1      59    158      122                   43
# 2332                           1     275    513      409                   62
# 3385                           1     126    301      264                    0
# ...                          ...     ...    ...      ...                  ...
# 188937                         1      41    203      161                    8
# 190627                         0      55    200      165                    0
# 190824                         1     130    320      258                    0
# 191226                         1     221    393      315                   12
# 191280                         1     187    835      673                   28
#
#         shipping_addresses  devices  vouchers  cc_payments  paypal_payments  \
# 434                      2        2         6          171                0
# 1380                     2        4        24          203                0
# 1421                     4        2        26          117                1
# 2332                    16        4        60           23              176
# 3385                     1        2        29          301                0
# ...                    ...      ...       ...          ...              ...
# 188937                   3        4        13           78              122
# 190627                   4        3        22           50               45
# 190824                   1        4        47          320                0
# 191226                  20        4        80          118               33
# 191280                   4        4        55          832                2
#
#         afterpay_payments  female_items  male_items  unisex_items  wapp_items  \
# 434                     0           171           0             0         161
# 1380                    0           165          33             5          98
# 1421                   40           157           1             0         133
# 2332                  314           467          18            28         388
# 3385                    0           294           0             7         271
# ...                   ...           ...         ...           ...         ...
# 188937                  0           183          12             8         137
# 190627                105           197           1             2         124
# 190824                  0           311           6             3         199
# 191226                241           366           8            19         310
# 191280                  0           753          60            22         638
#
#         wftw_items  mapp_items  wacc_items  macc_items  mftw_items  \
# 434              7           0           1           0           0
# 1380            63          24           4           6           5
# 1421            14           0           7           1           0
# 2332            41           3          35          12          16
# 3385            19           1           4           3           0
# ...            ...         ...         ...         ...         ...
# 188937          37           9           8           7           2
# 190627          51           0          18           0           2
# 190824          75           5          32           1           2
# 191226          30          12          26           6           0
# 191280          52          43          45          12          11
#
#         sprt_items  msite_orders  desktop_orders  android_orders  ios_orders  \
# 434              0             3               3               0          23
# 1380             0             8              22               0          51
# 1421             1             0              29               0          30
# 2332             1            51             104               0         120
# 3385             1             8              87               0          31
# ...            ...           ...             ...             ...         ...
# 188937           0             3              14               0          24
# 190627           1             6              48               0           1
# 190824           3             2              65               0          63
# 191226           4             7              66               0         148
# 191280          26             3             130               5          49
#
#         work_orders  home_orders  parcelpoint_orders  coupon_discount_applied  \
# 434              29            0                   0                   0.0289
# 1380              0           76                   0                   0.1568
# 1421             23           19                   0                   0.1017
# 2332             90          130                   0                   0.1096
# 3385              0          113                   0                   0.0648
# ...             ...          ...                 ...                      ...
# 188937            2           36                   0                   0.1980
# 190627            1           42                   0                   0.2194
# 190824            0          114                   0                   0.1286
# 191226           31          153                   0                   0.1530
# 191280            0          170                   0                   0.2099
#
#          revenue   customer_id
# 434     11807.06  3.035680e+09
# 1380    12109.75  3.071641e+09
# 1421    11066.28  3.073042e+09
# 2332    43952.80  3.107201e+09
# 3385    30953.32  3.021650e+09
# ...          ...           ...
# 188937  14373.19  3.722216e+09
# 190627   8133.41  3.732393e+09
# 190824  19845.60  3.738113e+09
# 191226  28865.52  3.704876e+09
# 191280  68349.19  3.706954e+09
#
# [274 rows x 33 columns]

# %%
# Items is the sum of female_items, male_items and unisex_items. As it does not provide additional information, I will therefore drop it later on.

df_raw.loc[df_raw['items']!=df_raw['female_items']+df_raw['male_items']+df_raw['unisex_items']]
# Out:
# Empty DataFrame
# Columns: [days_since_first_order, days_since_last_order, is_newsletter_subscriber, orders, items, returns, different_addresses, shipping_addresses, devices, vouchers, cc_payments, paypal_payments, afterpay_payments, female_items, male_items, unisex_items, wapp_items, wftw_items, mapp_items, wacc_items, macc_items, mftw_items, sprt_items, msite_orders, desktop_orders, android_orders, ios_orders, work_orders, home_orders, parcelpoint_orders, coupon_discount_applied, revenue, customer_id]
# Index: []

# %% [markdown]
# ### Coupon_discount_applied

# %%
# 'coupon_discount_applied' is the average discount rate applied via coupon based discount e.g. SAVE15. 
# There shouldn't be any negative value nor value exceeding 100% (free item).

df_raw['coupon_discount_applied'].sort_values()
# Out:
# 25588    -1.559784e+02
# 0         0.000000e+00
# 111543    0.000000e+00
# 111544    0.000000e+00
# 111547    0.000000e+00
#               ...
# 147970    3.587900e+06
# 92881     3.839500e+06
# 18506     3.997600e+06
# 153627    4.541400e+06
# 147757    5.798000e+06
# Name: coupon_discount_applied, Length: 191287, dtype: float64

# %%
df_raw['coupon_discount_applied'].describe()
# Out:
# count    1.912870e+05
# mean     1.321704e+03
# std      3.905356e+04
# min     -1.559784e+02
# 25%      4.800000e-03
# 50%      5.520000e-02
# 75%      1.466000e-01
# max      5.798000e+06
# Name: coupon_discount_applied, dtype: float64

# %%
# Taking a look at the coupon over 100%.
print(f"Percentage of coupon over 100%: {df_raw.loc[df_raw['coupon_discount_applied'] >= 1, 'coupon_discount_applied'].count()*100/df_raw.shape[0]}")

plt.figure(figsize=(10,5))
df_raw.loc[df_raw['coupon_discount_applied'] >= 1, 'coupon_discount_applied'].sort_values().reset_index(drop=True).plot(kind='hist', bins=100)
plt.legend()
plt.title('Distribution of coupon of over 100%');
# Out:
# Percentage of coupon over 100%: 0.7062685911745179

# %% [markdown]
# ### Revenue

# %%
# Revenue = $ Dollar spent overall per person. 
# There shouldn't be any negative value.
df_raw['revenue'].sort_values()
# Out:
# 25588         -1.13
# 98595          0.00
# 158964         0.00
# 155432         0.00
# 152966         0.00
#             ...
# 153209    144518.41
# 128744    149182.19
# 5698      162312.55
# 25190     165326.80
# 117175    205655.02
# Name: revenue, Length: 191287, dtype: float64

# %%
df = df_raw.copy()

# %%
# Let's replace the negative value by 0. We will tackle the 0 values later on.

df.loc[df['revenue']<0,'revenue'] = 0

# %%
# Let's take a look at records having a revenue/items ratio of less than 1.

df_small_revenue = df[['items','revenue']].copy()
df_small_revenue['ratio'] = df['revenue']/df['items']
df_small_revenue.loc[df_small_revenue['ratio']<=1].sort_values(by='ratio')

# Those records look suspicious. 
# Maybe one reason for having items that didn't generate revenue could be free gift?...
# I think it would be wise to replace those 0 later.
# Out:
#         items  revenue  ratio
# 1543        1     0.00   0.00
# 154005      1     0.00   0.00
# 153999      1     0.00   0.00
# 153667      2     0.00   0.00
# 153627      9     0.00   0.00
# ...       ...      ...    ...
# 90171       1     0.87   0.87
# 190078      2     1.74   0.87
# 175848      1     0.87   0.87
# 76563       1     0.89   0.89
# 5833        1     0.91   0.91
#
# [485 rows x 3 columns]

# %%
# Is the average revenue per item (for revenue and revenue/items ratio over quantile 90%) disproportionate? 

big_revenue = df['revenue'] > df['revenue'].quantile(0.9)
big_ratio = df['revenue']/df['items'] > (df['revenue']/df['items']).quantile(0.9)

df_average_revenue_per_item = df.loc[(big_revenue) & (big_ratio),['items','revenue']]
df_average_revenue_per_item['average_revenue_per_item'] = df_average_revenue_per_item['revenue']/df_average_revenue_per_item['items']
df_average_revenue_per_item.sort_values(by='average_revenue_per_item', ascending=False)

# This looks fine to me.
# Out:
#         items   revenue  average_revenue_per_item
# 104461     11   4074.46                370.405455
# 73712      22   8103.23                368.328636
# 122660     11   4039.38                367.216364
# 165856     13   3955.79                304.291538
# 26084      16   4570.68                285.667500
# ...       ...       ...                       ...
# 56608      36   3863.69                107.324722
# 113375     42   4507.03                107.310238
# 73766     424  45485.15                107.276297
# 185579    328  35186.19                107.274970
# 69732      37   3968.94                107.268649
#
# [1415 rows x 3 columns]

# %%
df_average_revenue_per_item['average_revenue_per_item'].describe()

# Nothing much to comment here
# Out:
# count    1415.000000
# mean      130.958592
# std        27.543073
# min       107.268649
# 25%       113.816379
# 50%       122.441724
# 75%       138.057589
# max       370.405455
# Name: average_revenue_per_item, dtype: float64

# %%
# Checking the items where the revenue is 0

df.loc[df['revenue']==0,'items'].value_counts().index
# Out:
# Int64Index([1, 2, 3, 5, 4, 6, 7, 9, 8, 13, 12], dtype='int64')

# %%
# Replacing each 'revenue' having 0 by the median of revenue for its specific number of items (1 to 13)

for i in df.loc[df['revenue']==0,'items'].value_counts().index:  
    replace = df.loc[df['revenue'] != 0].groupby('items')['revenue'].median()[i]
    print(f"median for {i} items = {replace}")
    print('')
    print(df.loc[(df['revenue']==0) & (df['items']==i),['items','revenue']])
    print('')
    df.loc[(df['revenue']==0) & (df['items']==i),'revenue']  = replace
# Out:
# median for 1 items = 63.61
#
#         items  revenue
# 1543        1      0.0
# 7588        1      0.0
# 9342        1      0.0
# 11278       1      0.0
# 11560       1      0.0
# ...       ...      ...
# 188594      1      0.0
# 190056      1      0.0
# 190092      1      0.0
# 190923      1      0.0
# 191267      1      0.0
#
# [291 rows x 2 columns]
#
# median for 2 items = 109.05
#
#         items  revenue
# 1614        2      0.0
# 17574       2      0.0
# 19010       2      0.0
# 24031       2      0.0
# 29814       2      0.0
# ...       ...      ...
# 184620      2      0.0
# 186319      2      0.0
# 187197      2      0.0
# 187375      2      0.0
# 187933      2      0.0
#
# [95 rows x 2 columns]
#
# median for 3 items = 163.49
#
#         items  revenue
# 1619        3      0.0
# 7364        3      0.0
# 49288       3      0.0
# 59681       3      0.0
# 78481       3      0.0
# 88799       3      0.0
# 90679       3      0.0
# 93086       3      0.0
# 93594       3      0.0
# 99517       3      0.0
# 100450      3      0.0
# 106961      3      0.0
# 114777      3      0.0
# 125877      3      0.0
# 133839      3      0.0
# 147573      3      0.0
# 147923      3      0.0
# 152244      3      0.0
# 155210      3      0.0
# 155432      3      0.0
# 157661      3      0.0
# 158964      3      0.0
# 159731      3      0.0
# 167315      3      0.0
# 172919      3      0.0
# 173277      3      0.0
# 173591      3      0.0
# 185426      3      0.0
# 188654      3      0.0
# 190675      3      0.0
#
# median for 5 items = 278.95
#
#         items  revenue
# 18506       5      0.0
# 90081       5      0.0
# 93438       5      0.0
# 104949      5      0.0
# 106187      5      0.0
# 115438      5      0.0
# 127448      5      0.0
# 145217      5      0.0
# 176420      5      0.0
# 186812      5      0.0
#
# median for 4 items = 215.8
#
#         items  revenue
# 74490       4      0.0
# 121441      4      0.0
# 126153      4      0.0
# 141459      4      0.0
# 150080      4      0.0
# 155930      4      0.0
# 156479      4      0.0
# 158320      4      0.0
# 183405      4      0.0
# 189549      4      0.0
#
# median for 6 items = 323.33000000000004
#
#         items  revenue
# 110089      6      0.0
# 147970      6      0.0
# 150172      6      0.0
# 160154      6      0.0
# 180446      6      0.0
# 183432      6      0.0
#
# median for 7 items = 390.97
#
#         items  revenue
# 110991      7      0.0
# 125480      7      0.0
# 147757      7      0.0
#
# median for 9 items = 500.31
#
#         items  revenue
# 153627      9      0.0
# 168502      9      0.0
#
# median for 8 items = 442.88
#
#         items  revenue
# 25588       8      0.0
# 170188      8      0.0
#
# median for 13 items = 729.52
#
#        items  revenue
# 92881     13      0.0
#
# median for 12 items = 658.7349999999999
#
#         items  revenue
# 173008     12      0.0

# %%
# Let's take a look at the big revenue in details

list_avg_max = []
for i in sorted(df['items'].unique()):
    print(f"For {i} items the average max revenue is {df.loc[df['items']==i,'revenue'].max()/i}")
    list_avg_max.append(df.loc[df['items']==i,'revenue'].max()/i)
# Out:
# For 1 items the average max revenue is 981.82
# For 2 items the average max revenue is 680.905
# For 3 items the average max revenue is 545.75
# For 4 items the average max revenue is 498.185
# For 5 items the average max revenue is 335.268
# For 6 items the average max revenue is 319.955
# For 7 items the average max revenue is 314.14285714285717
# For 8 items the average max revenue is 362.49
# For 9 items the average max revenue is 300.7688888888889
# For 10 items the average max revenue is 328.569
# For 11 items the average max revenue is 370.4054545454546
# For 12 items the average max revenue is 198.10333333333332
# For 13 items the average max revenue is 304.29153846153844
# For 14 items the average max revenue is 254.95499999999998
# For 15 items the average max revenue is 276.59000000000003
# For 16 items the average max revenue is 285.6675
# For 17 items the average max revenue is 270.7117647058824
# For 18 items the average max revenue is 238.67166666666668
# For 19 items the average max revenue is 216.58
# For 20 items the average max revenue is 210.23600000000002
# For 21 items the average max revenue is 221.7590476190476
# For 22 items the average max revenue is 368.32863636363635
# For 23 items the average max revenue is 204.5204347826087
# For 24 items the average max revenue is 214.21375
# For 25 items the average max revenue is 217.4348
# For 26 items the average max revenue is 195.4803846153846
# For 27 items the average max revenue is 191.17111111111112
# For 28 items the average max revenue is 185.42499999999998
# For 29 items the average max revenue is 210.2551724137931
# For 30 items the average max revenue is 171.02766666666668
# For 31 items the average max revenue is 165.3841935483871
# For 32 items the average max revenue is 186.8328125
# For 33 items the average max revenue is 187.17454545454547
# For 34 items the average max revenue is 172.95617647058825
# For 35 items the average max revenue is 218.00514285714286
# For 36 items the average max revenue is 225.92055555555555
# For 37 items the average max revenue is 149.98432432432432
# For 38 items the average max revenue is 178.74763157894736
# For 39 items the average max revenue is 282.4020512820513
# For 40 items the average max revenue is 168.509
# For 41 items the average max revenue is 206.49682926829271
# For 42 items the average max revenue is 220.42809523809524
# For 43 items the average max revenue is 192.88813953488372
# For 44 items the average max revenue is 199.5043181818182
# For 45 items the average max revenue is 204.06
# For 46 items the average max revenue is 168.80152173913044
# For 47 items the average max revenue is 159.92489361702127
# For 48 items the average max revenue is 231.87354166666668
# For 49 items the average max revenue is 169.19857142857143
# For 50 items the average max revenue is 157.5822
# For 51 items the average max revenue is 171.91411764705884
# For 52 items the average max revenue is 189.0469230769231
# For 53 items the average max revenue is 240.14000000000001
# For 54 items the average max revenue is 148.49333333333334
# For 55 items the average max revenue is 134.89618181818182
# For 56 items the average max revenue is 161.27089285714285
# For 57 items the average max revenue is 151.1563157894737
# For 58 items the average max revenue is 160.50741379310347
# For 59 items the average max revenue is 138.49525423728815
# For 60 items the average max revenue is 173.5445
# For 61 items the average max revenue is 149.10442622950822
# For 62 items the average max revenue is 167.8932258064516
# For 63 items the average max revenue is 137.63380952380953
# For 64 items the average max revenue is 221.88875
# For 65 items the average max revenue is 154.3223076923077
# For 66 items the average max revenue is 166.8578787878788
# For 67 items the average max revenue is 197.63567164179105
# For 68 items the average max revenue is 126.72764705882352
# For 69 items the average max revenue is 133.12695652173915
# For 70 items the average max revenue is 127.60828571428571
# For 71 items the average max revenue is 187.26507042253522
# For 72 items the average max revenue is 248.9359722222222
# For 73 items the average max revenue is 141.10191780821918
# For 74 items the average max revenue is 146.73378378378376
# For 75 items the average max revenue is 145.88986666666668
# For 76 items the average max revenue is 135.51513157894738
# For 77 items the average max revenue is 169.16
# For 78 items the average max revenue is 136.77833333333334
# For 79 items the average max revenue is 158.17911392405063
# For 80 items the average max revenue is 142.96087500000002
# For 81 items the average max revenue is 165.9885185185185
# For 82 items the average max revenue is 168.51743902439026
# For 83 items the average max revenue is 185.85650602409638
# For 84 items the average max revenue is 130.81023809523808
# For 85 items the average max revenue is 137.51117647058825
# For 86 items the average max revenue is 135.67383720930232
# For 87 items the average max revenue is 215.50183908045977
# For 88 items the average max revenue is 145.23090909090908
# For 89 items the average max revenue is 143.0605617977528
# For 90 items the average max revenue is 120.47977777777778
# For 91 items the average max revenue is 171.17395604395605
# For 92 items the average max revenue is 132.99858695652173
# For 93 items the average max revenue is 127.79537634408601
# For 94 items the average max revenue is 129.07712765957447
# For 95 items the average max revenue is 130.3802105263158
# For 96 items the average max revenue is 146.90083333333334
# For 97 items the average max revenue is 143.44268041237115
# For 98 items the average max revenue is 131.0707142857143
# For 99 items the average max revenue is 124.4020202020202
# For 100 items the average max revenue is 159.5067
# For 101 items the average max revenue is 141.49683168316832
# For 102 items the average max revenue is 117.80725490196079
# For 103 items the average max revenue is 176.55699029126214
# For 104 items the average max revenue is 169.44951923076923
# For 105 items the average max revenue is 131.83352380952383
# For 106 items the average max revenue is 141.51150943396226
# For 107 items the average max revenue is 128.7470093457944
# For 108 items the average max revenue is 132.98212962962964
# For 109 items the average max revenue is 153.20605504587155
# For 110 items the average max revenue is 115.85463636363636
# For 111 items the average max revenue is 156.5717117117117
# For 112 items the average max revenue is 136.15026785714286
# For 113 items the average max revenue is 145.891592920354
# For 114 items the average max revenue is 122.63315789473684
# For 115 items the average max revenue is 120.22765217391304
# For 116 items the average max revenue is 236.39396551724138
# For 117 items the average max revenue is 103.26452991452992
# For 118 items the average max revenue is 142.20677966101695
# For 119 items the average max revenue is 129.54529411764705
# For 120 items the average max revenue is 142.5615
# For 121 items the average max revenue is 128.95561983471075
# For 122 items the average max revenue is 129.50024590163935
# For 123 items the average max revenue is 184.89747967479676
# For 124 items the average max revenue is 148.91951612903227
# For 125 items the average max revenue is 108.67448
# For 126 items the average max revenue is 238.57166666666666
# For 127 items the average max revenue is 138.92511811023624
# For 128 items the average max revenue is 171.0034375
# For 129 items the average max revenue is 115.27643410852713
# For 130 items the average max revenue is 150.706
# For 131 items the average max revenue is 106.78335877862597
# For 132 items the average max revenue is 141.6987121212121
# For 133 items the average max revenue is 132.52052631578948
# For 134 items the average max revenue is 97.18082089552239
# For 135 items the average max revenue is 154.3974814814815
# For 136 items the average max revenue is 128.76507352941175
# For 137 items the average max revenue is 103.68795620437956
# For 138 items the average max revenue is 185.78028985507245
# For 139 items the average max revenue is 127.52417266187051
# For 140 items the average max revenue is 114.20735714285715
# For 141 items the average max revenue is 162.81347517730498
# For 142 items the average max revenue is 98.16633802816902
# For 143 items the average max revenue is 117.26209790209789
# For 144 items the average max revenue is 121.00020833333332
# For 145 items the average max revenue is 138.35151724137933
# For 146 items the average max revenue is 107.96130136986302
# For 147 items the average max revenue is 119.85442176870747
# For 148 items the average max revenue is 116.78344594594596
# For 149 items the average max revenue is 127.88912751677852
# For 150 items the average max revenue is 110.54886666666668
# For 151 items the average max revenue is 104.42847682119206
# For 152 items the average max revenue is 118.87835526315789
# For 153 items the average max revenue is 150.1839869281046
# For 154 items the average max revenue is 110.25571428571429
# For 155 items the average max revenue is 88.09535483870968
# For 156 items the average max revenue is 102.35596153846154
# For 157 items the average max revenue is 107.05751592356687
# For 158 items the average max revenue is 160.3510759493671
# For 159 items the average max revenue is 148.1374213836478
# For 160 items the average max revenue is 104.2266875
# For 161 items the average max revenue is 107.85906832298137
# For 162 items the average max revenue is 157.8120987654321
# For 163 items the average max revenue is 110.6978527607362
# For 164 items the average max revenue is 96.13006097560975
# For 165 items the average max revenue is 106.61084848484849
# For 166 items the average max revenue is 113.5794578313253
# For 167 items the average max revenue is 99.41203592814372
# For 168 items the average max revenue is 143.27255952380952
# For 169 items the average max revenue is 116.45970414201183
# For 170 items the average max revenue is 127.34982352941176
# For 171 items the average max revenue is 158.4861403508772
# For 172 items the average max revenue is 109.30912790697674
# For 173 items the average max revenue is 176.13312138728324
# For 174 items the average max revenue is 89.71632183908045
# For 175 items the average max revenue is 120.38325714285715
# For 176 items the average max revenue is 95.82107954545454
# For 177 items the average max revenue is 127.30926553672317
# For 178 items the average max revenue is 132.1279213483146
# For 179 items the average max revenue is 120.4845810055866
# For 180 items the average max revenue is 141.38666666666666
# For 181 items the average max revenue is 94.70055248618785
# For 182 items the average max revenue is 91.40642857142858
# For 183 items the average max revenue is 200.02579234972677
# For 184 items the average max revenue is 132.46652173913043
# For 185 items the average max revenue is 163.32124324324323
# For 186 items the average max revenue is 116.31876344086022
# For 187 items the average max revenue is 120.44508021390374
# For 188 items the average max revenue is 119.65382978723403
# For 189 items the average max revenue is 119.0351851851852
# For 190 items the average max revenue is 105.46231578947369
# For 191 items the average max revenue is 100.5760732984293
# For 192 items the average max revenue is 131.32416666666668
# For 193 items the average max revenue is 94.60051813471503
# For 194 items the average max revenue is 103.2781443298969
# For 195 items the average max revenue is 133.24297435897435
# For 196 items the average max revenue is 106.51270408163266
# For 197 items the average max revenue is 133.1786802030457
# For 198 items the average max revenue is 111.73237373737373
# For 199 items the average max revenue is 116.98778894472362
# For 200 items the average max revenue is 115.69555
# For 201 items the average max revenue is 129.63592039800994
# For 202 items the average max revenue is 127.0048514851485
# For 203 items the average max revenue is 103.2484236453202
# For 204 items the average max revenue is 104.49279411764705
# For 205 items the average max revenue is 115.37024390243903
# For 206 items the average max revenue is 108.43592233009709
# For 207 items the average max revenue is 80.24980676328502
# For 208 items the average max revenue is 80.7783653846154
# For 209 items the average max revenue is 90.40588516746412
# For 210 items the average max revenue is 142.0322857142857
# For 211 items the average max revenue is 138.07265402843603
# For 212 items the average max revenue is 142.39033018867926
# For 213 items the average max revenue is 106.8331455399061
# For 214 items the average max revenue is 132.5532710280374
# For 215 items the average max revenue is 94.55767441860466
# For 216 items the average max revenue is 90.24328703703704
# For 217 items the average max revenue is 99.4410599078341
# For 218 items the average max revenue is 149.92678899082568
# For 219 items the average max revenue is 100.02716894977169
# For 220 items the average max revenue is 100.97981818181819
# For 221 items the average max revenue is 155.61149321266967
# For 222 items the average max revenue is 111.23324324324324
# For 223 items the average max revenue is 131.21255605381165
# For 224 items the average max revenue is 135.4883482142857
# For 225 items the average max revenue is 105.73373333333333
# For 226 items the average max revenue is 115.17035398230088
# For 227 items the average max revenue is 75.89563876651982
# For 228 items the average max revenue is 99.04837719298246
# For 229 items the average max revenue is 142.74471615720523
# For 230 items the average max revenue is 227.36908695652173
# For 231 items the average max revenue is 101.52666666666667
# For 232 items the average max revenue is 90.24086206896553
# For 233 items the average max revenue is 131.4321888412017
# For 234 items the average max revenue is 109.77820512820512
# For 235 items the average max revenue is 91.40748936170212
# For 236 items the average max revenue is 92.37177966101696
# For 237 items the average max revenue is 172.34928270042192
# For 238 items the average max revenue is 110.09247899159664
# For 239 items the average max revenue is 110.24092050209205
# For 240 items the average max revenue is 77.01825000000001
# For 241 items the average max revenue is 107.19734439834025
# For 242 items the average max revenue is 88.18413223140496
# For 243 items the average max revenue is 81.74736625514403
# For 244 items the average max revenue is 89.25381147540983
# For 245 items the average max revenue is 84.75424489795918
# For 246 items the average max revenue is 89.9940243902439
# For 247 items the average max revenue is 113.0151012145749
# For 248 items the average max revenue is 126.70729838709677
# For 249 items the average max revenue is 79.1879919678715
# For 250 items the average max revenue is 118.63692
# For 251 items the average max revenue is 92.32223107569722
# For 252 items the average max revenue is 90.72087301587301
# For 253 items the average max revenue is 108.70715415019762
# For 254 items the average max revenue is 77.971062992126
# For 255 items the average max revenue is 87.91274509803921
# For 256 items the average max revenue is 110.942265625
# For 257 items the average max revenue is 98.35093385214007
# For 258 items the average max revenue is 95.92
# For 259 items the average max revenue is 93.22552123552123
# For 260 items the average max revenue is 113.5676153846154
# For 261 items the average max revenue is 66.40513409961686
# For 262 items the average max revenue is 97.91824427480917
# For 263 items the average max revenue is 116.37653992395437
# For 264 items the average max revenue is 85.73890151515151
# For 265 items the average max revenue is 103.75845283018869
# For 266 items the average max revenue is 146.9717293233083
# For 267 items the average max revenue is 99.83464419475655
# For 268 items the average max revenue is 96.67320895522387
# For 269 items the average max revenue is 80.68408921933086
# For 270 items the average max revenue is 90.24314814814815
# For 271 items the average max revenue is 83.31276752767528
# For 272 items the average max revenue is 105.93220588235295
# For 273 items the average max revenue is 102.12498168498168
# For 274 items the average max revenue is 105.36817518248175
# For 275 items the average max revenue is 119.67163636363635
# For 276 items the average max revenue is 129.46264492753625
# For 277 items the average max revenue is 135.15747292418774
# For 278 items the average max revenue is 89.10924460431654
# For 279 items the average max revenue is 98.12168458781362
# For 280 items the average max revenue is 95.62100000000001
# For 281 items the average max revenue is 82.02508896797153
# For 282 items the average max revenue is 73.64581560283688
# For 283 items the average max revenue is 106.97512367491166
# For 284 items the average max revenue is 87.93323943661971
# For 285 items the average max revenue is 68.68985964912281
# For 286 items the average max revenue is 92.29384615384616
# For 287 items the average max revenue is 84.03484320557492
# For 288 items the average max revenue is 163.1663888888889
# For 289 items the average max revenue is 88.50103806228374
# For 290 items the average max revenue is 89.92589655172414
# For 291 items the average max revenue is 115.13563573883162
# For 292 items the average max revenue is 129.0575
# For 293 items the average max revenue is 77.58542662116041
# For 294 items the average max revenue is 77.11023809523809
# For 295 items the average max revenue is 88.78586440677967
# For 296 items the average max revenue is 77.00442567567568
# For 297 items the average max revenue is 85.1720202020202
# For 298 items the average max revenue is 64.71046979865773
# For 299 items the average max revenue is 100.15862876254181
# For 300 items the average max revenue is 77.10013333333333
# For 301 items the average max revenue is 102.83495016611296
# For 302 items the average max revenue is 84.8078476821192
# For 303 items the average max revenue is 87.36897689768976
# For 304 items the average max revenue is 100.18032894736842
# For 305 items the average max revenue is 80.15177049180328
# For 306 items the average max revenue is 70.65725490196078
# For 307 items the average max revenue is 79.25622149837133
# For 308 items the average max revenue is 69.5775974025974
# For 309 items the average max revenue is 96.64207119741101
# For 310 items the average max revenue is 71.86141935483872
# For 311 items the average max revenue is 99.11765273311897
# For 312 items the average max revenue is 79.60875
# For 313 items the average max revenue is 58.689137380191696
# For 314 items the average max revenue is 90.79226114649681
# For 315 items the average max revenue is 122.65355555555557
# For 316 items the average max revenue is 132.5218670886076
# For 317 items the average max revenue is 70.84299684542587
# For 318 items the average max revenue is 94.61971698113207
# For 319 items the average max revenue is 85.30012539184953
# For 320 items the average max revenue is 102.53118750000002
# For 321 items the average max revenue is 70.87598130841121
# For 322 items the average max revenue is 186.85440993788822
# For 323 items the average max revenue is 88.1643653250774
# For 324 items the average max revenue is 81.41385802469136
# For 325 items the average max revenue is 75.40944615384615
# For 326 items the average max revenue is 99.08601226993865
# For 327 items the average max revenue is 151.64318042813454
# For 328 items the average max revenue is 107.27496951219513
# For 329 items the average max revenue is 92.04343465045594
# For 330 items the average max revenue is 72.78978787878788
# For 331 items the average max revenue is 79.91172205438066
# For 332 items the average max revenue is 56.70686746987952
# For 333 items the average max revenue is 139.71342342342342
# For 334 items the average max revenue is 64.98287425149701
# For 335 items the average max revenue is 166.94874626865672
# For 336 items the average max revenue is 82.10574404761904
# For 337 items the average max revenue is 75.59314540059347
# For 338 items the average max revenue is 91.46168639053255
# For 339 items the average max revenue is 124.04890855457228
# For 340 items the average max revenue is 97.37608823529412
# For 341 items the average max revenue is 80.5841348973607
# For 342 items the average max revenue is 82.10672514619883
# For 343 items the average max revenue is 84.9338192419825
# For 344 items the average max revenue is 80.11720930232558
# For 345 items the average max revenue is 100.72550724637682
# For 346 items the average max revenue is 83.64277456647399
# For 347 items the average max revenue is 69.18610951008647
# For 348 items the average max revenue is 60.38063218390804
# For 349 items the average max revenue is 74.21449856733524
# For 350 items the average max revenue is 85.69874285714286
# For 351 items the average max revenue is 144.69150997151
# For 352 items the average max revenue is 76.05
# For 353 items the average max revenue is 44.00682719546742
# For 354 items the average max revenue is 140.5237570621469
# For 355 items the average max revenue is 112.05884507042254
# For 356 items the average max revenue is 66.46738764044943
# For 357 items the average max revenue is 65.18890756302521
# For 358 items the average max revenue is 84.03251396648045
# For 359 items the average max revenue is 109.16270194986073
# For 360 items the average max revenue is 85.60733333333333
# For 361 items the average max revenue is 45.44783933518005
# For 362 items the average max revenue is 92.3986187845304
# For 363 items the average max revenue is 69.36823691460054
# For 364 items the average max revenue is 85.11925824175825
# For 365 items the average max revenue is 89.50679452054794
# For 366 items the average max revenue is 196.35161202185793
# For 367 items the average max revenue is 89.5599455040872
# For 368 items the average max revenue is 89.34157608695651
# For 369 items the average max revenue is 114.86222222222223
# For 370 items the average max revenue is 92.09694594594595
# For 371 items the average max revenue is 107.8390835579515
# For 372 items the average max revenue is 100.77634408602151
# For 373 items the average max revenue is 82.23959785522788
# For 374 items the average max revenue is 96.59687165775402
# For 375 items the average max revenue is 101.09448
# For 376 items the average max revenue is 93.18093085106382
# For 377 items the average max revenue is 91.99761273209549
# For 379 items the average max revenue is 67.83831134564645
# For 380 items the average max revenue is 130.47663157894738
# For 381 items the average max revenue is 76.20703412073492
# For 382 items the average max revenue is 93.05049738219896
# For 383 items the average max revenue is 185.06522193211487
# For 384 items the average max revenue is 47.93403645833333
# For 385 items the average max revenue is 54.05348051948052
# For 386 items the average max revenue is 78.05134715025906
# For 387 items the average max revenue is 110.72950904392765
# For 388 items the average max revenue is 62.900618556701026
# For 389 items the average max revenue is 83.63997429305913
# For 390 items the average max revenue is 70.9328717948718
# For 391 items the average max revenue is 77.4131969309463
# For 392 items the average max revenue is 99.24204081632652
# For 393 items the average max revenue is 73.44916030534351
# For 394 items the average max revenue is 85.26271573604062
# For 395 items the average max revenue is 97.37724050632912
# For 396 items the average max revenue is 78.6740404040404
# For 397 items the average max revenue is 100.22380352644836
# For 398 items the average max revenue is 76.20394472361808
# For 399 items the average max revenue is 86.60338345864662
# For 400 items the average max revenue is 61.29105
# For 401 items the average max revenue is 78.34209476309228
# For 402 items the average max revenue is 42.255920398009955
# For 403 items the average max revenue is 83.3333746898263
# For 404 items the average max revenue is 71.49910891089108
# For 405 items the average max revenue is 95.07669135802469
# For 406 items the average max revenue is 90.45463054187192
# For 407 items the average max revenue is 79.69496314496314
# For 408 items the average max revenue is 94.67105392156863
# For 409 items the average max revenue is 62.10457212713936
# For 410 items the average max revenue is 71.88619512195122
# For 411 items the average max revenue is 115.60063260340632
# For 412 items the average max revenue is 120.99089805825243
# For 413 items the average max revenue is 68.62249394673124
# For 414 items the average max revenue is 84.94900966183575
# For 415 items the average max revenue is 75.41486746987951
# For 416 items the average max revenue is 73.44663461538461
# For 417 items the average max revenue is 99.07611510791367
# For 418 items the average max revenue is 100.8017942583732
# For 419 items the average max revenue is 83.04031026252983
# For 420 items the average max revenue is 77.00604761904762
# For 422 items the average max revenue is 90.62741706161137
# For 423 items the average max revenue is 152.41356973995272
# For 424 items the average max revenue is 107.27629716981133
# For 425 items the average max revenue is 82.83689411764706
# For 426 items the average max revenue is 102.38638497652582
# For 427 items the average max revenue is 88.79690866510538
# For 428 items the average max revenue is 75.19205607476636
# For 429 items the average max revenue is 59.436713286713285
# For 430 items the average max revenue is 97.75188372093022
# For 431 items the average max revenue is 89.70816705336428
# For 432 items the average max revenue is 80.08064814814814
# For 433 items the average max revenue is 74.43997690531178
# For 434 items the average max revenue is 70.33610599078341
# For 435 items the average max revenue is 88.69535632183909
# For 436 items the average max revenue is 61.30747706422019
# For 437 items the average max revenue is 101.31951945080091
# For 438 items the average max revenue is 96.57698630136987
# For 439 items the average max revenue is 91.00202733485193
# For 440 items the average max revenue is 63.56231818181818
# For 441 items the average max revenue is 65.3749433106576
# For 442 items the average max revenue is 83.24794117647058
# For 443 items the average max revenue is 64.33505643340858
# For 444 items the average max revenue is 33.28702702702703
# For 445 items the average max revenue is 67.5405617977528
# For 446 items the average max revenue is 70.16708520179372
# For 447 items the average max revenue is 78.7834004474273
# For 448 items the average max revenue is 115.64520089285715
# For 449 items the average max revenue is 56.76318485523385
# For 450 items the average max revenue is 73.89208888888889
# For 451 items the average max revenue is 52.046341463414635
# For 452 items the average max revenue is 67.28643805309734
# For 453 items the average max revenue is 72.8846357615894
# For 455 items the average max revenue is 79.66384615384617
# For 456 items the average max revenue is 52.46026315789474
# For 457 items the average max revenue is 94.93870897155361
# For 459 items the average max revenue is 54.9841394335512
# For 460 items the average max revenue is 65.36919565217391
# For 461 items the average max revenue is 42.67965292841649
# For 462 items the average max revenue is 47.08025974025974
# For 463 items the average max revenue is 88.38548596112312
# For 465 items the average max revenue is 68.86006451612903
# For 467 items the average max revenue is 83.57197002141328
# For 468 items the average max revenue is 102.2923076923077
# For 469 items the average max revenue is 98.44650319829425
# For 470 items the average max revenue is 55.12421276595745
# For 471 items the average max revenue is 86.5351804670913
# For 472 items the average max revenue is 40.39773305084746
# For 473 items the average max revenue is 115.78355179704018
# For 475 items the average max revenue is 55.84088421052631
# For 476 items the average max revenue is 51.538823529411765
# For 477 items the average max revenue is 36.334549266247386
# For 478 items the average max revenue is 43.21033472803347
# For 479 items the average max revenue is 104.87599164926931
# For 480 items the average max revenue is 60.4939375
# For 481 items the average max revenue is 129.80532224532226
# For 482 items the average max revenue is 100.26072614107883
# For 484 items the average max revenue is 101.55915289256198
# For 487 items the average max revenue is 44.25285420944559
# For 488 items the average max revenue is 86.51786885245902
# For 489 items the average max revenue is 72.10196319018405
# For 490 items the average max revenue is 32.97538775510204
# For 491 items the average max revenue is 65.10725050916497
# For 492 items the average max revenue is 107.83166666666666
# For 493 items the average max revenue is 70.94947261663285
# For 494 items the average max revenue is 71.11755060728746
# For 495 items the average max revenue is 43.101090909090914
# For 498 items the average max revenue is 80.30672690763052
# For 499 items the average max revenue is 43.60579158316634
# For 501 items the average max revenue is 57.360678642714575
# For 503 items the average max revenue is 128.43771371769384
# For 504 items the average max revenue is 39.01674603174603
# For 505 items the average max revenue is 80.24990099009901
# For 506 items the average max revenue is 64.18069169960475
# For 507 items the average max revenue is 50.651124260355026
# For 508 items the average max revenue is 67.7961811023622
# For 509 items the average max revenue is 86.9812180746562
# For 510 items the average max revenue is 84.98317647058823
# For 511 items the average max revenue is 80.46344422700587
# For 512 items the average max revenue is 83.616640625
# For 513 items the average max revenue is 85.67797270955167
# For 514 items the average max revenue is 86.95700389105059
# For 516 items the average max revenue is 64.81031007751939
# For 517 items the average max revenue is 49.28112185686654
# For 518 items the average max revenue is 56.58040540540541
# For 519 items the average max revenue is 50.43314065510597
# For 520 items the average max revenue is 53.53373076923077
# For 521 items the average max revenue is 94.40028790786948
# For 524 items the average max revenue is 95.08040076335877
# For 525 items the average max revenue is 67.26300952380953
# For 527 items the average max revenue is 67.43986717267552
# For 528 items the average max revenue is 86.50696969696969
# For 530 items the average max revenue is 77.05466037735849
# For 533 items the average max revenue is 28.346810506566605
# For 534 items the average max revenue is 64.80438202247191
# For 535 items the average max revenue is 56.468280373831774
# For 536 items the average max revenue is 80.12792910447762
# For 537 items the average max revenue is 97.4388454376164
# For 538 items the average max revenue is 70.72308550185873
# For 539 items the average max revenue is 28.825677179962895
# For 541 items the average max revenue is 83.54012939001848
# For 543 items the average max revenue is 74.90565377532228
# For 545 items the average max revenue is 52.230366972477064
# For 548 items the average max revenue is 44.77910583941606
# For 549 items the average max revenue is 90.6652641165756
# For 552 items the average max revenue is 63.78786231884058
# For 553 items the average max revenue is 60.1603616636528
# For 554 items the average max revenue is 53.97303249097473
# For 557 items the average max revenue is 52.63759425493716
# For 558 items the average max revenue is 60.75790322580646
# For 562 items the average max revenue is 78.81608540925266
# For 564 items the average max revenue is 53.25709219858156
# For 565 items the average max revenue is 46.06191150442478
# For 566 items the average max revenue is 100.4000706713781
# For 567 items the average max revenue is 105.3974250440917
# For 570 items the average max revenue is 77.55612280701754
# For 572 items the average max revenue is 48.029597902097905
# For 574 items the average max revenue is 107.7141637630662
# For 576 items the average max revenue is 62.36402777777778
# For 577 items the average max revenue is 61.32287694974004
# For 579 items the average max revenue is 67.86136442141624
# For 580 items the average max revenue is 71.26234482758622
# For 581 items the average max revenue is 112.88857142857142
# For 583 items the average max revenue is 81.24969125214407
# For 584 items the average max revenue is 114.04777397260273
# For 587 items the average max revenue is 88.94388415672913
# For 588 items the average max revenue is 64.9398469387755
# For 591 items the average max revenue is 64.34920473773265
# For 594 items the average max revenue is 53.413148148148146
# For 598 items the average max revenue is 77.58511705685619
# For 599 items the average max revenue is 54.32288814691152
# For 601 items the average max revenue is 100.0610149750416
# For 602 items the average max revenue is 63.55091362126246
# For 604 items the average max revenue is 78.41756622516556
# For 605 items the average max revenue is 78.78748760330579
# For 607 items the average max revenue is 68.27856672158154
# For 608 items the average max revenue is 68.23733552631579
# For 610 items the average max revenue is 81.43150819672131
# For 616 items the average max revenue is 42.97647727272727
# For 617 items the average max revenue is 81.12936790923825
# For 618 items the average max revenue is 70.08894822006472
# For 621 items the average max revenue is 68.39818035426731
# For 624 items the average max revenue is 80.56424679487179
# For 625 items the average max revenue is 48.632448
# For 629 items the average max revenue is 70.04489666136725
# For 630 items the average max revenue is 65.18779365079365
# For 632 items the average max revenue is 44.96813291139241
# For 633 items the average max revenue is 52.44382306477094
# For 634 items the average max revenue is 116.20294952681388
# For 636 items the average max revenue is 42.11328616352201
# For 640 items the average max revenue is 70.9410625
# For 644 items the average max revenue is 73.0016149068323
# For 647 items the average max revenue is 58.1198145285935
# For 649 items the average max revenue is 53.013343605547
# For 653 items the average max revenue is 59.63286370597244
# For 655 items the average max revenue is 89.2861679389313
# For 657 items the average max revenue is 48.02503805175038
# For 659 items the average max revenue is 42.078406676783004
# For 664 items the average max revenue is 96.2865813253012
# For 668 items the average max revenue is 91.6891616766467
# For 669 items the average max revenue is 91.81699551569507
# For 674 items the average max revenue is 64.59176557863502
# For 675 items the average max revenue is 56.370074074074076
# For 676 items the average max revenue is 76.88349112426035
# For 678 items the average max revenue is 24.197654867256635
# For 681 items the average max revenue is 30.946563876651982
# For 683 items the average max revenue is 120.2205270863836
# For 686 items the average max revenue is 71.55772594752186
# For 688 items the average max revenue is 71.34834302325582
# For 690 items the average max revenue is 136.86389855072463
# For 691 items the average max revenue is 107.59617945007237
# For 693 items the average max revenue is 56.61721500721501
# For 702 items the average max revenue is 74.44242165242166
# For 706 items the average max revenue is 49.85626062322946
# For 707 items the average max revenue is 74.88055162659124
# For 708 items the average max revenue is 47.54718926553673
# For 709 items the average max revenue is 60.75880112834979
# For 710 items the average max revenue is 123.6402676056338
# For 715 items the average max revenue is 85.31756643356643
# For 716 items the average max revenue is 88.4933938547486
# For 718 items the average max revenue is 62.73384401114206
# For 729 items the average max revenue is 86.5240329218107
# For 738 items the average max revenue is 51.11924119241193
# For 742 items the average max revenue is 47.223207547169814
# For 743 items the average max revenue is 151.182732166891
# For 745 items the average max revenue is 89.30465771812081
# For 750 items the average max revenue is 45.71176
# For 751 items the average max revenue is 83.18868175765645
# For 752 items the average max revenue is 45.51559840425532
# For 753 items the average max revenue is 108.98440903054448
# For 756 items the average max revenue is 86.24623015873016
# For 762 items the average max revenue is 62.00476377952756
# For 763 items the average max revenue is 62.37689384010485
# For 764 items the average max revenue is 63.37240837696335
# For 769 items the average max revenue is 76.62832249674902
# For 783 items the average max revenue is 129.38191570881224
# For 784 items the average max revenue is 110.30343112244898
# For 788 items the average max revenue is 75.27203045685279
# For 790 items the average max revenue is 52.571594936708856
# For 794 items the average max revenue is 50.16275818639799
# For 795 items the average max revenue is 93.5343144654088
# For 797 items the average max revenue is 56.911505646173154
# For 801 items the average max revenue is 86.46938826466916
# For 804 items the average max revenue is 62.337437810945275
# For 806 items the average max revenue is 58.968808933002485
# For 812 items the average max revenue is 81.5864039408867
# For 819 items the average max revenue is 38.40184371184371
# For 823 items the average max revenue is 98.29448359659781
# For 829 items the average max revenue is 66.06564535585042
# For 831 items the average max revenue is 34.48646209386282
# For 834 items the average max revenue is 95.23864508393285
# For 835 items the average max revenue is 81.85531736526946
# For 836 items the average max revenue is 86.35355263157895
# For 838 items the average max revenue is 65.98064439140812
# For 844 items the average max revenue is 77.35896919431279
# For 847 items the average max revenue is 50.05380165289256
# For 853 items the average max revenue is 58.68545134818289
# For 859 items the average max revenue is 56.18610011641444
# For 868 items the average max revenue is 59.75218894009217
# For 873 items the average max revenue is 103.54073310423826
# For 887 items the average max revenue is 162.92943630214205
# For 893 items the average max revenue is 87.3898320268757
# For 894 items the average max revenue is 120.45753914988813
# For 897 items the average max revenue is 102.90588628762542
# For 899 items the average max revenue is 57.10938820912124
# For 901 items the average max revenue is 104.67608213096558
# For 904 items the average max revenue is 38.13659292035398
# For 908 items the average max revenue is 55.50393171806167
# For 974 items the average max revenue is 77.77433264887064
# For 986 items the average max revenue is 108.45132860040567
# For 994 items the average max revenue is 65.34496981891348
# For 1003 items the average max revenue is 42.03736789631107
# For 1015 items the average max revenue is 59.2868275862069
# For 1019 items the average max revenue is 48.899489695780176
# For 1049 items the average max revenue is 13.078179218303147
# For 1099 items the average max revenue is 2.7461510464058234
# For 1102 items the average max revenue is 45.96328493647913
# For 1124 items the average max revenue is 87.76663701067615
# For 1137 items the average max revenue is 47.407607739665785
# For 1145 items the average max revenue is 119.99500436681222
# For 1211 items the average max revenue is 74.05869529314616
# For 1254 items the average max revenue is 57.343476874003194
# For 1275 items the average max revenue is 64.66823529411765
# For 1298 items the average max revenue is 47.317057010785824
# For 1323 items the average max revenue is 101.95967498110355
# For 1368 items the average max revenue is 85.86542397660818
# For 1426 items the average max revenue is 113.82366760168303
# For 1438 items the average max revenue is 76.70903337969402
# For 1561 items the average max revenue is 71.73620115310699
# For 1588 items the average max revenue is 73.961580604534
# For 1603 items the average max revenue is 4.603487211478478
# For 1605 items the average max revenue is 78.41769470404984
# For 2072 items the average max revenue is 71.99912644787645
# For 2209 items the average max revenue is 93.09869624264373
# For 2374 items the average max revenue is 6.171575400168492
# For 3020 items the average max revenue is 54.743973509933774

# %%
pd.Series(list_avg_max).describe()
# Out:
# count    674.000000
# mean     109.473350
# std       69.420527
# min        2.746151
# 25%       73.447266
# 50%       94.685803
# 75%      129.305719
# max      981.820000
# dtype: float64

# %%
# Those are the high revenue in regards to the items. These records might be seen as outliers.

pd.Series(list_avg_max).loc[np.abs(stats.zscore(pd.Series(list_avg_max)))>3]
# Out:
# 0     981.820000
# 1     680.905000
# 2     545.750000
# 3     498.185000
# 4     335.268000
# 5     319.955000
# 7     362.490000
# 9     328.569000
# 10    370.405455
# 21    368.328636
# dtype: float64

# %%
# A look at the big revenues

list_big_revenue = pd.Series(list_avg_max).loc[np.abs(stats.zscore(pd.Series(list_avg_max)))>3].tolist()
df.loc[(df['revenue']/df['items']).isin(list_big_revenue)]
# Out:
#         days_since_first_order  days_since_last_order  \
# 24476                     1406                    452
# 46981                     1318                    159
# 64601                     2669                    928
# 65881                     2406                    257
# 73712                     1768                   1031
# 91482                     2332                    207
# 104461                    2361                    111
# 118726                    2488                   1165
# 142344                    2376                   2187
# 174486                    2476                   1168
#
#         is_newsletter_subscriber  orders  items  returns  different_addresses  \
# 24476                          1      10     10        1                    0
# 46981                          0       3      3        0                    0
# 64601                          1       8      8        4                    0
# 65881                          1       6      6        4                    0
# 73712                          1      10     22        1                    0
# 91482                          1       3      5        0                    0
# 104461                         1       8     11        1                    0
# 118726                         1       1      2        0                    0
# 142344                         0       4      4        2                    0
# 174486                         1       1      1        1                    0
#
#         shipping_addresses  devices  vouchers  cc_payments  paypal_payments  \
# 24476                    2        1         0           10                0
# 46981                    2        2         1            0                3
# 64601                    5        2         0            8                0
# 65881                    1        1         2            6                0
# 73712                    3        1         3           20                2
# 91482                    2        1         0            3                2
# 104461                   4        1         1            0               11
# 118726                   1        1         0            2                0
# 142344                   1        1         2            2                0
# 174486                   1        1         1            0                1
#
#         afterpay_payments  female_items  male_items  unisex_items  wapp_items  \
# 24476                   0            10           0             0           9
# 46981                   0             2           1             0           0
# 64601                   0             8           0             0           6
# 65881                   0             6           0             0           6
# 73712                   0            19           3             0          17
# 91482                   0             5           0             0           5
# 104461                  0            10           0             1           8
# 118726                  0             2           0             0           0
# 142344                  0             4           0             0           4
# 174486                  0             1           0             0           1
#
#         wftw_items  mapp_items  wacc_items  macc_items  mftw_items  \
# 24476            1           0           0           0           0
# 46981            2           0           0           1           0
# 64601            2           0           0           0           0
# 65881            0           0           0           0           0
# 73712            1           3           1           0           0
# 91482            0           0           0           0           0
# 104461           3           0           0           0           0
# 118726           0           0           2           0           0
# 142344           0           0           0           0           0
# 174486           0           0           0           0           0
#
#         sprt_items  msite_orders  desktop_orders  android_orders  ios_orders  \
# 24476            0             0              10               0           0
# 46981            0             2               1               0           0
# 64601            0             8               0               0           0
# 65881            0             0               6               0           0
# 73712            0             0              10               0           0
# 91482            0             1               0               0           2
# 104461           0             8               0               0           0
# 118726           0             0               1               0           0
# 142344           0             0               4               0           0
# 174486           0             0               1               0           0
#
#         work_orders  home_orders  parcelpoint_orders  coupon_discount_applied  \
# 24476             0           10                   0                   0.0003
# 46981             0            3                   0                   0.0055
# 64601             0            5                   0                   0.0000
# 65881             0            6                   0                   0.1731
# 73712             7            0                   0                   0.0882
# 91482             0            2                   0                   0.0005
# 104461            2            5                   0                   0.0295
# 118726            0            1                   0                   0.0007
# 142344            0            0                   0                   0.0857
# 174486            0            1                   0                   0.3333
#
#         revenue   customer_id
# 24476   3285.69  3.030160e+09
# 46981   1637.25  3.156814e+09
# 64601   2899.92  3.213947e+09
# 65881   1919.73  3.267805e+09
# 73712   8103.23  3.321476e+09
# 91482   1676.34  3.370639e+09
# 104461  4074.46  3.422682e+09
# 118726  1361.81  3.509139e+09
# 142344  1992.74  3.568523e+09
# 174486   981.82  3.692687e+09

# %% [markdown]
# ## Preliminary Exploration before Machine Learning models

# %%
df_cleaned = df_raw.copy()

# Convert 'is_newsletter_subscriber' into 1 or 0 (1='Yes', 0 ='No').
df_cleaned['is_newsletter_subscriber'] = np.where(df_cleaned['is_newsletter_subscriber']=='Y',1,0)

''' Features engineering'''

# Create another feature for the average of revenue spend per item
df_cleaned['avg_revenue_per_item'] = df_cleaned['revenue']/df_cleaned['items']

# Create another feature for the number of items per order
df_cleaned['items_per_order'] = df_cleaned['items']/df_cleaned['orders']

# Create another feature for the number of returns
df_cleaned['returns_per_item'] = df_cleaned['returns']*100/df_cleaned['items']

# Create another feature for the online orders
df_cleaned['online_orders'] = (df_cleaned['msite_orders'] + df_cleaned['desktop_orders'] + df_cleaned['android_orders'] + df_cleaned['ios_orders'])/ df_cleaned['orders']

# Create another feature for the shipped items
df_cleaned['shipped_items'] = (df_cleaned['work_orders'] + df_cleaned['home_orders'] + df_cleaned['parcelpoint_orders'])/ df_cleaned['orders']

# Create another feature for female items
df_cleaned['f_items'] = df_cleaned['female_items'] + df_cleaned['wapp_items'] + df_cleaned['wacc_items'] + df_cleaned['wftw_items']

# Create another feature for male items
df_cleaned['m_items'] = df_cleaned['male_items'] + df_cleaned['mapp_items'] + df_cleaned['macc_items'] + df_cleaned['mftw_items']

# Create another feature for the sum of payment method
df_cleaned['electronic_payment'] = (df_cleaned['cc_payments'] + df_cleaned['paypal_payments'] + df_cleaned['afterpay_payments'])/ df_cleaned['orders']

''' Creation of labels for "obvious" customers'''

# df_cleaned = df_cleaned.loc[(np.abs(stats.zscore(df_cleaned.drop('is_newsletter_subscriber',axis=1)))<3).all(axis=1)]
df_cleaned = df_cleaned.loc[(df_cleaned['male_items']+df_cleaned['female_items']>=10) & (df_cleaned[['female_items','male_items']].max(axis=1)/df_cleaned[['female_items','male_items']].min(axis=1)>=4)]

df_cleaned.loc[df_cleaned['female_items']/df_cleaned['male_items']>= 4,'label_created'] = 1
df_cleaned.loc[df_cleaned['male_items']/df_cleaned['female_items']>= 4,'label_created'] = 0

remove_sample = df_cleaned['label_created'].value_counts().max() - df_cleaned['label_created'].value_counts().min()
drop_indices = np.random.choice(df_cleaned.loc[df_cleaned['label_created']==df_cleaned['label_created'].value_counts().index[0]].index, remove_sample, replace=False)
df_cleaned = df_cleaned.drop(drop_indices)

# Replace the negative 'revenue' value by 0
df_cleaned.loc[df_cleaned['revenue']<0,'revenue'] = 0

# Replace each 'revenue' having 0 by the median of revenue for its specific number of items (1 to 13)
for i in df_cleaned.loc[df_cleaned['revenue']==0,'items'].value_counts().index:  
    replace = df_cleaned.loc[df_cleaned['revenue'] != 0].groupby('items')['revenue'].median()[i]
    df_cleaned.loc[(df_cleaned['revenue']==0) & (df_cleaned['items']==i),'revenue'] = replace

# %%
df_cleaned['label_created'].value_counts()
# Out:
# 1.0    9790
# 0.0    9790
# Name: label_created, dtype: int64

# %%
df_mean = df_cleaned.groupby('label_created').mean()
df_mean
# Out:
#                days_since_first_order  days_since_last_order  \
# label_created
# 0.0                       2392.304494             553.301124
# 1.0                       2367.757712             314.787538
#
#                is_newsletter_subscriber     orders      items    returns  \
# label_created
# 0.0                                 0.0  13.135546  33.264658   4.811645
# 1.0                                 0.0  23.171195  54.487743  17.966803
#
#                different_addresses  shipping_addresses   devices  vouchers  \
# label_created
# 0.0                       2.079775            3.012564  1.839122  4.159040
# 1.0                       2.639632            3.709908  2.153933  7.419816
#
#                cc_payments  paypal_payments  afterpay_payments  female_items  \
# label_created
# 0.0              20.197446         9.766190           2.409704      1.003473
# 1.0              29.090501        17.493156           6.861287     50.569459
#
#                male_items  unisex_items  wapp_items  wftw_items  mapp_items  \
# label_created
# 0.0             30.398876      1.862308    0.466905    0.300409   20.910215
# 1.0              2.499591      1.418693   36.226864    9.242697    1.445046
#
#                wacc_items  macc_items  mftw_items  sprt_items  msite_orders  \
# label_created
# 0.0              0.311440    4.527886    5.478958    0.538202      2.002656
# 1.0              4.137998    0.864964    0.754239    0.439939      5.855260
#
#                desktop_orders  android_orders  ios_orders  work_orders  \
# label_created
# 0.0                  8.538304        0.387743    2.206844     1.359244
# 1.0                 11.639837        0.475996    5.200102     2.875689
#
#                home_orders  parcelpoint_orders  coupon_discount_applied  \
# label_created
# 0.0               6.542799            0.155363                 0.117003
# 1.0              13.491318            0.225332                 0.115830
#
#                    revenue   customer_id  avg_revenue_per_item  \
# label_created
# 0.0            1752.737293  3.383603e+09             52.001427
# 1.0            3431.072553  3.366967e+09             62.278613
#
#                items_per_order  returns_per_item  online_orders  \
# label_created
# 0.0                   2.843431         11.967068            1.0
# 1.0                   2.398098         25.746847            1.0
#
#                shipped_items     f_items    m_items  electronic_payment
# label_created
# 0.0                 0.543683    2.082227  61.315935            2.770607
# 1.0                 0.666725  100.177017   5.563841            2.357458

# %%
df_med = df_cleaned.groupby('label_created').median()
df_med
# Out:
#                days_since_first_order  days_since_last_order  \
# label_created
# 0.0                            2437.0                  263.0
# 1.0                            2436.0                   91.5
#
#                is_newsletter_subscriber  orders  items  returns  \
# label_created
# 0.0                                 0.0    10.0   22.0      1.0
# 1.0                                 0.0    15.0   31.0      6.0
#
#                different_addresses  shipping_addresses  devices  vouchers  \
# label_created
# 0.0                            0.0                 3.0      2.0       3.0
# 1.0                            0.0                 3.0      2.0       5.0
#
#                cc_payments  paypal_payments  afterpay_payments  female_items  \
# label_created
# 0.0                   13.0              2.0                0.0           0.0
# 1.0                   14.0              6.0                0.0          29.0
#
#                male_items  unisex_items  wapp_items  wftw_items  mapp_items  \
# label_created
# 0.0                  20.0           1.0         0.0         0.0        13.0
# 1.0                   1.0           0.0        20.0         6.0         0.0
#
#                wacc_items  macc_items  mftw_items  sprt_items  msite_orders  \
# label_created
# 0.0                   0.0         3.0         4.0         0.0           1.0
# 1.0                   2.0         0.0         0.0         0.0           2.0
#
#                desktop_orders  android_orders  ios_orders  work_orders  \
# label_created
# 0.0                       6.0             0.0         0.0          0.0
# 1.0                       7.0             0.0         0.0          0.0
#
#                home_orders  parcelpoint_orders  coupon_discount_applied  \
# label_created
# 0.0                    4.0                 0.0                  0.08815
# 1.0                    8.0                 0.0                  0.09610
#
#                 revenue   customer_id  avg_revenue_per_item  items_per_order  \
# label_created
# 0.0            1155.145  3.390210e+09             49.502966         2.428571
# 1.0            1916.190  3.365544e+09             58.197000         2.128388
#
#                returns_per_item  online_orders  shipped_items  f_items  \
# label_created
# 0.0                    6.250000            1.0       0.592906      0.0
# 1.0                   21.545093            1.0       0.731707     57.5
#
#                m_items  electronic_payment
# label_created
# 0.0               41.0            2.375000
# 1.0                2.0            2.090909

# %%
# Plot mean and median of each feature

fig, axes = plt.subplots(2,1,figsize=(15,15))

df_mean[df_mean<=102].dropna(axis=1).T.plot(kind='bar', ax=axes[0])
df_med[df_med<=102].dropna(axis=1).T.plot(kind='bar', ax=axes[1])

axes[0].set_title('Mean of each feature for both female and male labels')
axes[1].set_title('Median of each feature for both female and male labels')

plt.tight_layout();

# %%
# Plot last 3 features

fig, axes = plt.subplots(2,1,figsize=(10,5))

df_mean[['days_since_first_order','days_since_last_order','revenue']].T.plot(kind='bar', ax=axes[0], rot=1)
df_mean[['days_since_first_order','days_since_last_order','revenue']].T.plot(kind='bar', ax=axes[1], rot=1)

axes[0].set_title('Mean of each feature for both female and male labels')
axes[1].set_title('Median of each feature for both female and male labels')


plt.tight_layout();

# %%
# A look at the correlation between features

plt.figure(figsize=(10,8))
sns.heatmap(df_cleaned.drop('label_created', axis=1).corr(), cmap=sns.diverging_palette(230, 20, as_cmap=True));

# %%
# A look at the features with more than 70% correlation

correlated_features = set()
correlation_matrix = df_cleaned.drop('label_created', axis=1).corr()

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.7:
            colname1 = correlation_matrix.columns[i]
            colname2 = correlation_matrix.columns[j]
            correlated_features.add(colname1)
            correlated_features.add(colname2)

correlated_features
# Out:
# {'cc_payments',
#  'days_since_last_order',
#  'desktop_orders',
#  'electronic_payment',
#  'f_items',
#  'female_items',
#  'home_orders',
#  'items',
#  'items_per_order',
#  'm_items',
#  'macc_items',
#  'male_items',
#  'mapp_items',
#  'mftw_items',
#  'orders',
#  'returns',
#  'revenue',
#  'shipped_items',
#  'vouchers',
#  'wacc_items',
#  'wapp_items',
#  'wftw_items'}

# %%
print("Let's keep the features 'days_since_last_order', 'orders', 'avg_revenue_per_item', 'f_items','m_items', 'returns_per_item'")
# Out:
# Let's keep the features 'days_since_last_order', 'orders', 'avg_revenue_per_item', 'f_items','m_items', 'returns_per_item'

# %%
df_cleaned = df_cleaned[['days_since_last_order', 'orders', 'avg_revenue_per_item', 'f_items','m_items','returns_per_item', 'label_created']]

# %%
# Do we still have correlated features?

correlated_features = set()
correlation_matrix = df_cleaned.drop(['label_created'], axis=1).corr()

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.7:
            colname1 = correlation_matrix.columns[i]
            colname2 = correlation_matrix.columns[j]
            correlated_features.add(colname1)
            correlated_features.add(colname2)

print(f"Now we have {len(correlated_features)} correlated features in our dataset")
# Out:
# Now we have 0 correlated features in our dataset

# %%
# Create X_ and y_ in order to look at feature importance

X_ = df_cleaned.drop('label_created', axis=1).values
y_ = df_cleaned['label_created'].values

# %%
# Using recursive feature elimination and cross-validated section to judge of the importance of the features

rfecv = RFECV(estimator=LogisticRegression(max_iter=500), step=1, scoring='accuracy')
rfecv.fit(X_, y_)
# Out:
# RFECV(estimator=LogisticRegression(max_iter=500), scoring='accuracy')

# %%
# The most significant features

df_cleaned.columns[np.where(rfecv.support_ == True)[0]]
# Out:
# Index(['f_items', 'm_items'], dtype='object')

# %%
# Ploting the features coefficients with regards to Logistic Regression model

logr = LogisticRegression(max_iter=500)
logr.fit(X_, y_)
df_to_plot = pd.DataFrame(logr.coef_,columns=df_cleaned.drop('label_created', axis=1).columns)
df_to_plot.plot(kind='bar', figsize=(20,10))
plt.title("orders, days_since_last_order, and avg_revenue_per_item seem to have very little importance for our model compared to f_items and m_items");
